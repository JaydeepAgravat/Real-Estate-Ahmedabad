# %%
import warnings
import re
import ast
import numpy as np
import pandas as pd
from wordcloud import WordCloud
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['figure.figsize'] = (9, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
df = pd.read_csv('data/preprocessed_residential_apartment.csv')
dff = df.copy()

# %%
df.head(1)
# Out:
#                                          DESCRIPTION            CITY LOCALITY  \
# 0  Best in class property available at south bopa...  Ahmedabad West    Ghuma
#
#    BEDROOM_NUM  BATHROOM_NUM  BALCONY_NUM FLOOR_CATEGORY       BUILDING_TYPE  \
# 0          3.0           3.0          1.0    High Floors  Mid-rise buildings
#
#      AREA      PRICE            TOP_USPS CORNER_PROPERTY FURNISH_LABEL  \
# 0  1700.0  7971000.0  INFO NOT AVAILABLE               N   Unfurnished
#
#                                     PROP_DETAILS_URL
# 0  3-bhk-bedroom-apartment-flat-for-sale-in-ghuma...

# %%
df[['DESCRIPTION', 'CITY', 'LOCALITY', 'BUILDING_TYPE', 'PROP_DETAILS_URL']]
# Out:
#                                             DESCRIPTION             CITY  \
# 0     Best in class property available at south bopa...   Ahmedabad West
# 1     This is your chance to own a 3 bhk residential...   Ahmedabad West
# 2     We are the proud owners of this 3 bhk apartmen...   Ahmedabad West
# 3     This is your chance to a 3 bhk apartment / fla...   Ahmedabad West
# 4     Residential apartment for sell.The property co...   Ahmedabad East
# ...                                                 ...              ...
# 7825        1 bhk flat in aagam 99 residential property   Ahmedabad West
# 7826  Changodar & kerala industrial estate are well ...  Ahmedabad South
# 7827  We are the proud owners of this 2 bhk apartmen...      Gandhinagar
# 7828  Shivsai residency near malaya high jantanagar ...  Ahmedabad North
# 7829  The property is rented so income for an invest...  Ahmedabad North
#
#          LOCALITY       BUILDING_TYPE  \
# 0           Ghuma  Mid-rise buildings
# 1         Thaltej  Mid-rise buildings
# 2        Vejalpur  Low-rise buildings
# 3     Panjara pol  Low-rise buildings
# 4         Vastral  Mid-rise buildings
# ...           ...                 ...
# 7825      Sachana  Mid-rise buildings
# 7826        Bavla  Low-rise buildings
# 7827       Sughad  Low-rise buildings
# 7828   Chandkheda  Low-rise buildings
# 7829       Vadsar  Low-rise buildings
#
#                                        PROP_DETAILS_URL
# 0     3-bhk-bedroom-apartment-flat-for-sale-in-ghuma...
# 1     3-bhk-bedroom-apartment-flat-for-sale-in-gala-...
# 2     3-bhk-bedroom-apartment-flat-for-sale-in-baker...
# 3     3-bhk-bedroom-apartment-flat-for-sale-in-slok-...
# 4     3-bhk-bedroom-apartment-flat-for-sale-in-vastr...
# ...                                                 ...
# 7825  1-bhk-bedroom-apartment-flat-for-sale-in-aagam...
# 7826  1-bhk-bedroom-apartment-flat-for-sale-in-bavla...
# 7827  2-bhk-bedroom-apartment-flat-for-sale-in-parsh...
# 7828  3-bhk-bedroom-apartment-flat-for-sale-in-chand...
# 7829  1-bhk-bedroom-apartment-flat-for-sale-in-tata-...
#
# [7830 rows x 5 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
# Vectorize the descriptions
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df['DESCRIPTION'])

# Compute cosine similarity
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# Function to recommend similar apartments
def recommend_similar_apartments(prop_details_url, cosine_sim=cosine_sim, df=df):
    # Get the index of the apartment that matches the PROP_DETAILS_URL
    idx = df.index[df['PROP_DETAILS_URL'] == prop_details_url].tolist()[0]
    
    # Get the pairwise similarity scores of all apartments with that apartment
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the apartments based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the top 5 most similar apartments
    sim_scores = sim_scores[1:6]
    
    # Get the apartment indices
    apartment_indices = [i[0] for i in sim_scores]
    
    # Return the top 5 most similar apartments
    return df.iloc[apartment_indices]

# %%
# Example usage
user_input_url = df['PROP_DETAILS_URL'].iloc[0]
similar_apartments = recommend_similar_apartments(user_input_url)

# %%
similar_apartments
# Out:
#                                             DESCRIPTION             CITY  \
# 7643  Best in class property available at south bopa...   Ahmedabad West
# 7755  Best in class property available at south bopa...   Ahmedabad West
# 7644  Best in class property available at shela loca...   Ahmedabad West
# 7661  Best in class property available at shela loca...   Ahmedabad West
# 7071  Best in class property available at gota locat...  Ahmedabad North
#
#          LOCALITY  BEDROOM_NUM  BATHROOM_NUM  BALCONY_NUM FLOOR_CATEGORY  \
# 7643  South bopal          3.0           3.0          0.0     Low Floors
# 7755  South bopal          3.0           3.0          0.0    High Floors
# 7644        Shela          3.0           3.0          1.0    High Floors
# 7661        Shela          3.0           3.0          1.0    High Floors
# 7071         Gota          2.0           2.0          1.0     Low Floors
#
#            BUILDING_TYPE    AREA      PRICE            TOP_USPS  \
# 7643  Low-rise buildings  1513.6  7000000.0  INFO NOT AVAILABLE
# 7755  Low-rise buildings  1595.0  6500000.0  INFO NOT AVAILABLE
# 7644  Low-rise buildings  1661.0  6460000.0  INFO NOT AVAILABLE
# 7661  Low-rise buildings  1661.0  6700000.0  INFO NOT AVAILABLE
# 7071  Mid-rise buildings  1291.2  6000000.0  INFO NOT AVAILABLE
#
#      CORNER_PROPERTY  FURNISH_LABEL  \
# 7643               N      Furnished
# 7755               N  Semifurnished
# 7644               N    Unfurnished
# 7661               N    Unfurnished
# 7071               N    Unfurnished
#
#                                        PROP_DETAILS_URL
# 7643  3-bhk-bedroom-apartment-flat-for-sale-in-gold-...
# 7755  3-bhk-bedroom-apartment-flat-for-sale-in-kavis...
# 7644  3-bhk-bedroom-apartment-flat-for-sale-in-shela...
# 7661  3-bhk-bedroom-apartment-flat-for-sale-in-shela...
# 7071  2-bhk-bedroom-apartment-flat-for-sale-in-gota-...

# %%
# Load the model from disk
with open('model.pkl', 'rb') as f:
    loaded_model = pickle.load(f)

# Now you can use the loaded model to make predictions
loaded_model.predict(np.array(['Ahmedabad East', 'Mid-rise buildings', 'Semifurnished', 2.0, 2.0, 3.0, 882.0]).reshape(1,-1))
# Out:
# C:\Users\rohan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# array([4304438.71162715])

# %%
import pickle
import numpy as np

# %%
prop_details_url = df['PROP_DETAILS_URL'].iloc[0]

# %%
 df.index[df['PROP_DETAILS_URL'] == prop_details_url].tolist()[0]
# Out:
# 0

# %%
"https://www.99acres.com/" + df['PROP_DETAILS_URL'].iloc[1]
# Out:
# 'https://www.99acres.com/3-bhk-bedroom-apartment-flat-for-sale-in-gala-eternia-thaltej-ahmedabad-west-1700-sq-ft-spid-B73228757'

# %%
"https://www.99acres.com/" + df['PROP_DETAILS_URL']
# Out:
# 0       https://www.99acres.com/3-bhk-bedroom-apartmen...
# 1       https://www.99acres.com/3-bhk-bedroom-apartmen...
# 2       https://www.99acres.com/3-bhk-bedroom-apartmen...
# 3       https://www.99acres.com/3-bhk-bedroom-apartmen...
# 4       https://www.99acres.com/3-bhk-bedroom-apartmen...
#                               ...
# 7825    https://www.99acres.com/1-bhk-bedroom-apartmen...
# 7826    https://www.99acres.com/1-bhk-bedroom-apartmen...
# 7827    https://www.99acres.com/2-bhk-bedroom-apartmen...
# 7828    https://www.99acres.com/3-bhk-bedroom-apartmen...
# 7829    https://www.99acres.com/1-bhk-bedroom-apartmen...
# Name: PROP_DETAILS_URL, Length: 7830, dtype: object

# %%
# Function to recommend similar apartments
def recommend_similar_apartments(prop_details_url):
    # Load data for recommender system
    df = pd.read_csv('data/preprocessed_residential_apartment.csv')
    df['PROP_DETAILS_URL'] = 'https://www.99acres.com/' + df['PROP_DETAILS_URL']

    # Vectorize the descriptions
    tfidf = TfidfVectorizer(stop_words='english')
    tfidf_matrix = tfidf.fit_transform(df['DESCRIPTION'])

    # Compute cosine similarity
    cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

    idx = df.index[df['PROP_DETAILS_URL'] == prop_details_url].tolist()[0]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[0:6]
    apartment_indices = [i[0] for i in sim_scores]
    return df.iloc[apartment_indices]

# %%
recommend_similar_apartments("https://www.99acres.com/" + df['PROP_DETAILS_URL'].iloc[1])
# Out:
#                                             DESCRIPTION            CITY  \
# 1     This is your chance to own a 3 bhk residential...  Ahmedabad West
# 3     This is your chance to a 3 bhk apartment / fla...  Ahmedabad West
# 1834  This is your chance to own a 2 bhk residential...  Ahmedabad West
# 30    Redefine luxury with a world of comfort at a 4...     Gandhinagar
# 4428  New construction , fully furnished , main road...  Ahmedabad West
# 3258  2 bhk apartment available for sell in one of t...  Ahmedabad West
#
#              LOCALITY  BEDROOM_NUM  BATHROOM_NUM  BALCONY_NUM FLOOR_CATEGORY  \
# 1             Thaltej          3.0           3.0          4.0    High Floors
# 3         Panjara pol          3.0           3.0          2.0     Low Floors
# 1834  Narmada vasahat          2.0           2.0          1.0     Low Floors
# 30             Sughad          4.0           3.0          3.0     Low Floors
# 4428          Thaltej          3.0           3.0          1.0    High Floors
# 3258      South bopal          2.0           2.0          1.0    High Floors
#
#            BUILDING_TYPE    AREA       PRICE  \
# 1     Mid-rise buildings  1700.0  18000000.0
# 3     Low-rise buildings  1936.8   9500000.0
# 1834  Mid-rise buildings  1215.0   4500000.0
# 30    Low-rise buildings  2808.0  12000000.0
# 4428  Mid-rise buildings  2394.0  29000000.0
# 3258  Mid-rise buildings  1250.0   6200000.0
#
#                                                TOP_USPS CORNER_PROPERTY  \
# 1     ['Fitness Center/ Gym', 'Club/ Community Center']               N
# 3                                    INFO NOT AVAILABLE               Y
# 1834                                 INFO NOT AVAILABLE               N
# 30                                   INFO NOT AVAILABLE               N
# 4428  ['Fitness Center/ Gym', 'Club/ Community Cente...               N
# 3258  ['East Facing', 'sarswati hospital within 1km'...               N
#
#       FURNISH_LABEL                                   PROP_DETAILS_URL
# 1     Semifurnished  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 3     Semifurnished  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 1834      Furnished  https://www.99acres.com/2-bhk-bedroom-apartmen...
# 30        Furnished  https://www.99acres.com/4-bhk-bedroom-apartmen...
# 4428  Semifurnished  https://www.99acres.com/3-bhk-bedroom-apartmen...
# 3258    Unfurnished  https://www.99acres.com/2-bhk-bedroom-apartmen...

# %%
 df['PROP_DETAILS_URL'] = 'https://www.99acres.com/' + df['PROP_DETAILS_URL']

# %%
 df['PROP_DETAILS_URL'].sample(1).iloc[0]
# Out:
# 'https://www.99acres.com/1-bhk-bedroom-apartment-flat-for-sale-in-adani-pratham-tragad-ahmedabad-north-450-sq-ft-spid-A74209487'
